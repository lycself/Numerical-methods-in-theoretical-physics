# %% [markdown]
# #  蒙特卡洛方法

# %% [markdown]
# ### 导入必要的 Python 库

# %%
import matplotlib.pyplot as plt # 导入图形库
import numpy as np
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ### 如何求$\pi$？
# $s = \pi r^2 $

# %%
#make a circle
t = np.linspace(0,2*np.pi,100)
X = np.sin(t)*1
Y = np.cos(t)*1

#draw
fig, ax = plt.subplots(figsize=(6, 5.9), layout='constrained')
ax.plot(X, Y, 'r', label='Standard Circle')
ax.set_xlim(-1.1,1.1)
ax.set_ylim(-1.1,1.1)

#ticks
ax.set_xlabel('x', fontsize=12, fontproperties='Times New Roman')
ax.set_ylabel('y', fontsize=12, fontproperties='Times New Roman')
ax.tick_params(size=3, labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]

#title
ax.set_title('Standart Circle, r=0.5',
             fontsize=10,
             fontproperties='Times New Roman')
#legend
ax.legend(loc=(0.73, 0.93), fontsize=10, frameon=True, prop='Times New Roman')

# %%
#make a circle
t = np.linspace(0,2*np.pi,100)
X = np.sin(t)*1
Y = np.cos(t)*1
N0=5000
np.random.seed(234)
X_random0=np.random.uniform(-1,1,N0)
Y_random0=np.random.uniform(-1,1,N0)


#draw
fig, ax = plt.subplots(figsize=(5, 4.9), layout='constrained')
ax.plot(X, Y, 'r', label='Standard Circle')
ax.plot(X_random0, Y_random0,'k.',alpha=0.2, label='Random Point')
ax.set_xlim(-1.1,1.1)
ax.set_ylim(-1.1,1.1)

#ticks
ax.set_xlabel('x', fontsize=12, fontproperties='Times New Roman')
ax.set_ylabel('y', fontsize=12, fontproperties='Times New Roman')
ax.tick_params(size=3, labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]

#title
ax.set_title('Monte Carlo, random spots, N=%i'%N0,
             fontsize=10,
             fontproperties='Times New Roman')
#legend
ax.legend(loc=(0.73, 0.9), fontsize=10, frameon=True, prop='Times New Roman')

#calculate loss
N_hit0=0
for i in np.arange(N0):
    if np.sqrt((X_random0[i]**2+Y_random0[i]**2))<1:
        N_hit0=N_hit0+1
r2=0.5**2
print("蒙卡结果：",(N_hit0/N0)*4,"\n","理论结果：",np.pi)
#fig.savefig('111.jpg')
# Out:
# 蒙卡结果： 3.1448
#  理论结果： 3.141592653589793

# %%
#make a circle
t = np.linspace(0,2*np.pi,100)
X = np.sin(t)*1
Y = np.cos(t)*1
N1=20000
np.random.seed(234)
X_random1=np.random.uniform(-1,1,N1)
Y_random1=np.random.uniform(-1,1,N1)


#draw
fig, ax = plt.subplots(figsize=(3.5, 2.99), layout='constrained')
ax.plot(X, Y, 'r', label='Standard Circle')
ax.plot(X_random1, Y_random1,'k.',alpha=0.05, label='Random Point')
ax.set_xlim(-1.1,1.1)
ax.set_ylim(-1.1,1.1)

#ticks
ax.set_xlabel('x', fontsize=12, fontproperties='Times New Roman')
ax.set_ylabel('y', fontsize=12, fontproperties='Times New Roman')
ax.tick_params(size=3, labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]

#title
ax.set_title('Monte Carlo, random spots, N=%i'%N1,
             fontsize=10,
             fontproperties='Times New Roman')
#legend
ax.legend(loc=(0.73, 0.9), fontsize=10, frameon=True, prop='Times New Roman')

#calculate loss
N_hit1=0
for i in np.arange(N1):
    if np.sqrt((X_random1[i]**2+Y_random1[i]**2))<1:
        N_hit1=N_hit1+1
r2=1**2
print("蒙卡结果：",(N_hit1/N1)*4,"\n","理论结果：",np.pi)
# Out:
# 蒙卡结果： 3.1432
#  理论结果： 3.141592653589793

# %%
fig, [ax1,ax2,ax3] = plt.subplots(1, 3, figsize=(10,2.3),dpi=350,sharey=True)
plt.subplots_adjust(left=0.1,
                    bottom=0.2, 
                    right=0.76, 
                    top=0.9, 
                    wspace=0.01, 
                    hspace=0.1)

ax1.plot(X, Y, 'r', label='Standard Circle')
ax1.set_xlim(-1.1,1.1)
ax1.set_ylim(-1.1,1.1)
ax1.set_yticks([-1., 0, 1.])
ax1.set_xticks([-1., 0, 1.])
ax1.set_title('N=0',
             fontsize=10,
             fontproperties='Times New Roman')
ax1.set_ylabel('y', fontsize=12, fontproperties='Times New Roman')
ax1.set_aspect('equal', adjustable='box')

ax2.plot(X, Y, 'r', label='Standard Circle')
ax2.plot(X_random0, Y_random0,'k.',alpha=0.1, label='Random Point')
ax2.set_xlim(-1.1,1.1)
#ax2.set_ylim(-1.1,1.1)
#ax2.set_yticks([-1., 0, 1.])
ax2.set_xticks([-1., 0, 1.])
ax2.set_title('N=5000',
             fontsize=10,
             fontproperties='Times New Roman')
ax2.set_xlabel('x', fontsize=12, fontproperties='Times New Roman')
ax2.set_aspect('equal', adjustable='box')


ax3.plot(X, Y, 'r', label='Standard Circle')
ax3.plot(X_random1, Y_random1,'k.',alpha=0.01, label='Random Point')
ax3.set_xlim(-1.1,1.1)
#ax3.set_ylim(-1.1,1.1)
#ax3.set_yticks([-1., 0, 1.])
ax3.set_xticks([-1., 0, 1.])
ax3.set_title('N=20000',
             fontsize=10,
             fontproperties='Times New Roman')
ax3.set_aspect('equal', adjustable='box')

lines, labels = fig.axes[1].get_legend_handles_labels()
fig.legend(lines, labels, loc = (0.77,0.5),fontsize=10, frameon=True, prop='Times New Roman') 
fig.savefig('222.jpg')

# %%
N=np.arange(1000,800000,10000)
N_hit=np.empty(len(N))
r2=0.5**2
for i in np.arange(len(N)):
    X_random=np.random.uniform(-1,1,N[i])
    Y_random=np.random.uniform(-1,1,N[i])
    N_h=0
    for ii in np.arange(N[i]):
        if np.sqrt((X_random[ii]**2+Y_random[ii]**2))<1:
            N_h=N_h+1
    N_hit[i]=(N_h/N[i])/r2
plt.plot(N,np.ones(len(N))*np.pi,"b-")
plt.plot(N,N_hit,"ro-")

# %%
#make a circle
#t = np.linspace(0,2*np.pi,100)
#X = np.sin(t)*1
#Y = np.cos(t)*1

#draw
fig, ax = plt.subplots(figsize=(7, 3), layout='constrained',dpi=350)
ax.plot(N,np.ones(len(N))*np.pi,"b--", label='Standard $\pi$')
ax.plot(N,N_hit,"ro--", alpha=0.5, label='Evaluate Value')
#ax.set_xscale('log',base=10)
#ax.set_xlim(-1.1,1.1)
#ax.set_ylim(-1.1,1.1)

#ticks
ax.set_xlabel('N', fontsize=10, fontproperties='Times New Roman')
ax.set_ylabel('Evaluate Value', fontsize=10, fontproperties='Times New Roman')
ax.tick_params(size=3, labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]

#title
#ax.set_title('Standart Circle, r=0.5',
            # fontsize=10,
             #fontproperties='Times New Roman')
#legend
ax.legend(loc=0, fontsize=10, frameon=True, prop='Times New Roman')
fig.savefig('333.jpg')

# %%
#draw
fig, ax = plt.subplots(figsize=(5, 2.99), layout='constrained',dpi=350)
ax.plot(n_trials_list,sigmasqs,"ro", label='Number of Sampling')
ax.plot(n_trials_list,0.4*4/np.sqrt(n_trials_list),'--')
#ax.set_xlim(-1.1,1.1)
ax.set_ylim(10e-3,1)

#ticks
ax.set_xlabel('N', fontsize=12, fontproperties='Times New Roman')
ax.set_ylabel('RMSD', fontsize=12, fontproperties='Times New Roman')
ax.set_xscale('log',base=10)
ax.set_yscale('log',base=10)
ax.tick_params(size=3, labelsize=10)
labels = ax.get_xticklabels() + ax.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]

#title
ax.set_title("RMSD vs N",
             fontsize=10,
             fontproperties='Times New Roman')
#legend
ax.legend(loc=0, fontsize=10, frameon=True, prop='Times New Roman')

#calculate loss
#N_hit1=0
#for i in np.arange(N1):
    #if np.sqrt((X_random1[i]**2+Y_random1[i]**2))<1:
       # N_hit1=N_hit1+1
#r2=1**2
#print("蒙卡结果：",(N_hit1/N1)*4,"\n","理论结果：",np.pi)
fig.savefig('444.jpg')

# %%
plt.loglog(n_trials_list,sigmasqs,"ro") #作点
plt.xlabel("N")
plt.ylabel("RMSD")
plt.title("RMSD vs N")
plt.loglog(n_trials_list,0.4*4/np.sqrt(n_trials_list),'--') #拟合直线
#plt.loglog(n_trials_list,sigmasqs,'--') #作点
#plt.grid(True)

# %% [markdown]
# ### 蒙卡方法2：Markov chain Monte Carlo algorithms

# %%
# Makov Chain sampling
x,y=0,0

delta=0.2 #最大步幅
n_trials=5000
Pos=np.zeros((n_trials,2))
n_hits=0
for i in np.arange(n_trials):
    del_x,del_y=np.random.uniform(-delta,delta,),np.random.uniform(-delta,delta,)
    if np.abs(x+del_x)<0.5 and np.abs(y+del_y)<0.5:
        x,y=x+del_x,y+del_y
    if x**2+y**2<0.5*0.5:
        n_hits+=1
    Pos[i,0]=x
    Pos[i,1]=y

# %%
t=np.linspace(0,2*3.1415926,100)
X=np.sin(t)*0.5
Y=np.cos(t)*0.5
plt.figure(figsize=(8,8))
plt.grid(True)
plt.ylim(-0.51,0.51)
plt.xlim(-0.51,0.51)
plt.plot(X,Y,'r-',lw=2)

plt.plot(Pos[:,0],Pos[:,1],"k.",alpha=0.2)
print("蒙卡结果：",n_hits/n_trials,"\n理论结果：",np.pi*0.5*0.5)
# Out:
# 蒙卡结果： 0.7958
# 理论结果： 0.7853981633974483

# %%
import matplotlib.pyplot as plt # 导入图形库
import numpy as np
from scipy import stats
# %matplotlib inline
bestcircle=[]
plt.figure(figsize=(16, 8))
for k in range(1,1500,1):
    delta=k*0.001
    x,y=0,0
    n_trials=500
    n_hits=0
    for i in np.arange(n_trials):
        del_x,del_y=np.random.uniform(-delta,delta,),np.random.uniform(-delta,delta,)
        if np.abs(x+del_x)<0.5 and np.abs(y+del_y)<0.5:
            x,y=x+del_x,y+del_y
        if x**2+y**2<0.5*0.5:
            n_hits+=1
    bestcircle.append(np.abs((n_hits/n_trials)-np.pi*0.5*0.5))
plt.xlabel("$The Biggest Strides$")
plt.ylabel("$Error$")
plt.title("$The Biggest Strides-Error$")
plt.plot(bestcircle,'r')
